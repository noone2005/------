# %%
i = 0
sum_result = 0
while i < 101:
    if i % 2 == 0:
        sum_result += i
    i += 1
print("1~100之间的偶数之和为：%s" % sum_result)
# Out:
# 1~100之间的偶数之和为：2550

# %%
for i in range(100,1000):
    s=str(i)
    one=int(s[-1])
    ten=int(s[-2])
    hun=int(s[-3])
    if i == one**3+ten**3+hun**3:
        print(i)
# Out:
# 153
# 370
# 371
# 407
